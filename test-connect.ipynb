# %%
from mongodb_controller import *

# %%
client
# Out:
# MongoClient(host=['cluster-life-shard-00-02.rbbcd.mongodb.net:27017', 'cluster-life-shard-00-00.rbbcd.mongodb.net:27017', 'cluster-life-shard-00-01.rbbcd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-xh4hp1-shard-0', tls=True)

# %%
db_test = client['database-test']
collection_hello = db_test['collection-hello']
data = collection_hello.find()

# %%
data.to_list()
# Out:
# [{'_id': ObjectId('67962c2396b275f4a7899cb3'),
#   'name': 'Test Fund',
#   'type': 'Equity',
#   'timestamp': '2025-01-26',
#   'value': 1000.5}]

# %%
from aws_s3_controller import *
# Out:
# INFO:aws_s3_controller:aws_s3_controller package initialized
# INFO:shining_pebbles:shining_pebbles package initialized

# %%
scan_files_in_bucket_by_regex(bucket='dataset-system', bucket_prefix='dataset-menuESAFE500068', regex='menuESAFE')
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# Files matching the regex 'menuESAFE' in the bucket 'dataset-system' with prefix 'dataset-menuESAFE500068':
# - dataset-menuESAFE500068/menuESAFE500068-account000000000-at00000000-save2025012517.xls
# - dataset-menuESAFE500068/menuESAFE500068-account000000000-at00000000-save2025012518.xls
# - dataset-menuESAFE500068/menuESAFE500068-account000000000-at00000000-save2025012519.xls
# - dataset-menuESAFE500068/menuESAFE500068-account000000000-at00000000-save2025012520.xls
# - dataset-menuESAFE500068/menuESAFE500068-account000000000-at00000000-save2025012521.xls
# - dataset-menuESAFE500068/menuESAFE500068-account000000000-at00000000-save2025012522.xls
# - dataset-menuESAFE500068/menuESAFE500068-account000000000-at00000000-save2025012603.xls
# - dataset-menuESAFE500068/menuESAFE500068-account000000000-at00000000-save2025012604.xls
# ...
